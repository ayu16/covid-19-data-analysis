# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()
import warnings
warnings.filterwarnings('ignore')

print('Modules are imported')
# Out:
# Modules are imported

# %%
corona_dataset_csv = pd.read_csv('time_series_covid19_confirmed_global.csv')
corona_dataset_csv.head(11)
# Out:
#                   Province/State       Country/Region       Lat        Long  \
# 0                            NaN          Afghanistan  33.93911   67.709953
# 1                            NaN              Albania  41.15330   20.168300
# 2                            NaN              Algeria  28.03390    1.659600
# 3                            NaN              Andorra  42.50630    1.521800
# 4                            NaN               Angola -11.20270   17.873900
# 5                            NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                            NaN            Argentina -38.41610  -63.616700
# 7                            NaN              Armenia  40.06910   45.038200
# 8   Australian Capital Territory            Australia -35.47350  149.012400
# 9                New South Wales            Australia -33.86880  151.209300
# 10            Northern Territory            Australia -12.46340  130.845600
#
# ...

# %%
corona_dataset_csv.shape
# Out:
# (275, 466)

# %%
corona_dataset_csv.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '4/18/21', '4/19/21', '4/20/21', '4/21/21', '4/22/21', '4/23/21',
#        '4/24/21', '4/25/21', '4/26/21', '4/27/21'],
#       dtype='object', length=466)

# %%
corona_dataset_csv.isnull().sum()
# Out:
# Province/State    189
# Country/Region      0
# Lat                 2
# Long                2
# 1/22/20             0
#                  ...
# 4/23/21             0
# 4/24/21             0
# 4/25/21             0
# 4/26/21             0
# 4/27/21             0
# Length: 466, dtype: int64

# %%
corona_dataset_csv.dtypes
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# 1/22/20             int64
#                    ...
# 4/23/21             int64
# 4/24/21             int64
# 4/25/21             int64
# 4/26/21             int64
# 4/27/21             int64
# Length: 466, dtype: object

# %%
corona_dataset_csv.info
# Out:
# <bound method DataFrame.info of     Province/State      Country/Region        Lat        Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110   67.709953        0
# 1              NaN             Albania  41.153300   20.168300        0
# 2              NaN             Algeria  28.033900    1.659600        0
# 3              NaN             Andorra  42.506300    1.521800        0
# 4              NaN              Angola -11.202700   17.873900        0
# ..             ...                 ...        ...         ...      ...
# 270            NaN             Vietnam  14.058324  108.277199        0
# 271            NaN  West Bank and Gaza  31.952200   35.233200        0
# 272            NaN               Yemen  15.552727   48.516388        0
# 273            NaN              Zambia -13.133897   27.849332        0
# 274            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/18/21  4/19/21  \
# ...

# %%
corona_dataset_csv.describe()
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  273.000000  273.000000  275.000000  275.000000  275.000000  275.000000
# mean    20.534804   23.028143    2.025455    2.381818    3.421818    5.210909
# std     25.194592   73.596166   26.830287   26.928190   33.524534   46.659184
# min    -51.796300 -178.116500    0.000000    0.000000    0.000000    0.000000
# 25%      5.152149  -19.020800    0.000000    0.000000    0.000000    0.000000
# 50%     21.694000   20.939400    0.000000    0.000000    0.000000    0.000000
# 75%     41.112900   84.250000    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000  444.000000  444.000000  549.000000  761.000000
#
#            1/26/20      1/27/20      1/28/20      1/29/20  ...       4/18/21  \
# count   275.000000   275.000000   275.000000   275.000000  ...  2.750000e+02
# mean      7.701818    10.643636    20.283636    22.425455  ...  5.142000e+05
# ...

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()
corona_dataset_aggregated.head(11)
# Out:
#                            Lat         Long  1/22/20  1/23/20  1/24/20  \
# Country/Region
# Afghanistan           33.93911    67.709953        0        0        0
# Albania               41.15330    20.168300        0        0        0
# Algeria               28.03390     1.659600        0        0        0
# Andorra               42.50630     1.521800        0        0        0
# Angola               -11.20270    17.873900        0        0        0
# Antigua and Barbuda   17.06080   -61.796400        0        0        0
# Argentina            -38.41610   -63.616700        0        0        0
# Armenia               40.06910    45.038200        0        0        0
# Australia           -256.85020  1130.843900        0        0        0
# Austria               47.51620    14.550100        0        0        0
# Azerbaijan            40.14310    47.576900        0        0        0
#
#                      1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  \
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (192, 464)

# %%
corona_dataset_aggregated.loc['China'].plot()
corona_dataset_aggregated.loc['Italy'].plot()
corona_dataset_aggregated.loc['Spain'].plot()
plt.legend()

# %%
corona_dataset_aggregated.loc['Australia'].plot()
corona_dataset_aggregated.loc['France'].plot()
corona_dataset_aggregated.loc['India'].plot()
plt.legend()

# %%
corona_dataset_aggregated.loc['China'].plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggregated.loc['India'].plot()
corona_dataset_aggregated.loc['US'].plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggregated.loc['China'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggregated.loc['India'].diff().plot()
corona_dataset_aggregated.loc['US'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc['India'].diff().max()
# Out:
# 360927.0

# %%
corona_dataset_aggregated.loc['France'].diff().max()
# Out:
# 117900.0

# %%
corona_dataset_aggregated.loc['Spain'].diff().max()
# Out:
# 93822.0

# %%
corona_dataset_aggregated.loc['Italy'].diff().max()
# Out:
# 40902.0

# %%
corona_dataset_aggregated.loc['Australia'].diff().max()
# Out:
# 1387.6941

# %%
corona_dataset_aggregated.loc['US'].diff().max()
# Out:
# 300310.0

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for country in countries:
    max_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['max infection rate'] = max_infection_rates
corona_dataset_aggregated.head()
# Out:
#                      Lat       Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Afghanistan     33.93911  67.709953        0        0        0        0
# Albania         41.15330  20.168300        0        0        0        0
# Algeria         28.03390   1.659600        0        0        0        0
# Andorra         42.50630   1.521800        0        0        0        0
# Angola         -11.20270  17.873900        0        0        0        0
#
#                 1/26/20  1/27/20  1/28/20  1/29/20  ...  4/19/21  4/20/21  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...    57898    58037
# Albania               0        0        0        0  ...   129694   129842
# Algeria               0        0        0        0  ...   119805   119992
# Andorra               0        0        0        0  ...    12805    12874
# Angola                0        0        0        0  ...    24518    24661
#
# ...

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated['max infection rate'])
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                 1485.0
# Albania                     1239.0
# Algeria                     1133.0
# Andorra                      299.0
# Angola                       355.0

# %%
world_happiness_report = pd.read_csv("2019.csv")
world_happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
world_happiness_report.shape
# Out:
# (156, 9)

# %%
world_happiness_report = pd.read_csv("2018.csv")
world_happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
world_happiness_report.shape
# Out:
# (156, 9)

# %%
world_happiness_report = pd.read_csv("2017.csv")
world_happiness_report.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
world_happiness_report.shape
# Out:
# (155, 12)

# %%
world_happiness_report = pd.read_csv("2016.csv")
world_happiness_report.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
world_happiness_report.shape
# Out:
# (157, 13)

# %%
world_happiness_report = pd.read_csv("2015.csv")
world_happiness_report.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
world_happiness_report.shape
# Out:
# (158, 12)

# %%
world_happiness_report.set_index(['Country'],inplace=True)
world_happiness_report.head()
# Out:
#                      Region  Happiness Rank  Happiness Score  Standard Error  \
# Country
# Switzerland  Western Europe               1            7.587         0.03411
# Iceland      Western Europe               2            7.561         0.04884
# Denmark      Western Europe               3            7.527         0.03328
# Norway       Western Europe               4            7.522         0.03880
# Canada        North America               5            7.427         0.03553
#
#              Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Switzerland                   1.39651  1.34951                   0.94143
# Iceland                       1.30232  1.40223                   0.94784
# Denmark                       1.32548  1.36058                   0.87464
# Norway                        1.45900  1.33095                   0.88521
# Canada                        1.32629  1.32261                   0.90563
#
# ...

# %%
world_happiness_report.set_index(['Region'],inplace=True)
world_happiness_report.head()
# Out:
#                 Happiness Rank  Happiness Score  Standard Error  \
# Region
# Western Europe               1            7.587         0.03411
# Western Europe               2            7.561         0.04884
# Western Europe               3            7.527         0.03328
# Western Europe               4            7.522         0.03880
# North America                5            7.427         0.03553
#
#                 Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Region
# Western Europe                   1.39651  1.34951                   0.94143
# Western Europe                   1.30232  1.40223                   0.94784
# Western Europe                   1.32548  1.36058                   0.87464
# Western Europe                   1.45900  1.33095                   0.88521
# North America                    1.32629  1.32261                   0.90563
#
#                 Freedom  Trust (Government Corruption)  Generosity  \
# Region
# ...

# %%
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                 1485.0
# Albania                     1239.0
# Algeria                     1133.0
# Andorra                      299.0
# Angola                       355.0

# %%
world_happiness_report.head()
# Out:
#                 Happiness Rank  Happiness Score  Standard Error  \
# Region
# Western Europe               1            7.587         0.03411
# Western Europe               2            7.561         0.04884
# Western Europe               3            7.527         0.03328
# Western Europe               4            7.522         0.03880
# North America                5            7.427         0.03553
#
#                 Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Region
# Western Europe                   1.39651  1.34951                   0.94143
# Western Europe                   1.30232  1.40223                   0.94784
# Western Europe                   1.32548  1.36058                   0.87464
# Western Europe                   1.45900  1.33095                   0.88521
# North America                    1.32629  1.32261                   0.90563
#
#                 Freedom  Trust (Government Corruption)  Generosity  \
# Region
# ...

# %%
data = world_happiness_report.join(corona_data).copy()
data.head()
# Out:
#                             Happiness Rank  Happiness Score  Standard Error  \
# Australia and New Zealand                9            7.286         0.03371
# Australia and New Zealand               10            7.284         0.04083
# Central and Eastern Europe              31            6.505         0.04168
# Central and Eastern Europe              44            6.003         0.04361
# Central and Eastern Europe              45            5.995         0.04267
#
#                             Economy (GDP per Capita)   Family  \
# Australia and New Zealand                    1.25018  1.31967
# Australia and New Zealand                    1.33358  1.30923
# Central and Eastern Europe                   1.17898  1.20643
# Central and Eastern Europe                   0.63244  1.34043
# Central and Eastern Europe                   1.16891  1.26999
#
#                             Health (Life Expectancy)  Freedom  \
# Australia and New Zealand                    0.90837  0.63938
# ...

# %%
data.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
# max infection rate                        NaN              NaN
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# ...

# %%
data.head()
# Out:
#                             Happiness Rank  Happiness Score  Standard Error  \
# Australia and New Zealand                9            7.286         0.03371
# Australia and New Zealand               10            7.284         0.04083
# Central and Eastern Europe              31            6.505         0.04168
# Central and Eastern Europe              44            6.003         0.04361
# Central and Eastern Europe              45            5.995         0.04267
#
#                             Economy (GDP per Capita)   Family  \
# Australia and New Zealand                    1.25018  1.31967
# Australia and New Zealand                    1.33358  1.30923
# Central and Eastern Europe                   1.17898  1.20643
# Central and Eastern Europe                   0.63244  1.34043
# Central and Eastern Europe                   1.16891  1.26999
#
#                             Health (Life Expectancy)  Freedom  \
# Australia and New Zealand                    0.90837  0.63938
# ...

# %%
x = data['Economy (GDP per Capita)']
y = data['Freedom']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Freedom'>

# %%
sns.regplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Freedom'>

# %%
x = data['Economy (GDP per Capita)']
y = data['Health (Life Expectancy)']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Health (Life Expectancy)'>

# %%
sns.regplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Health (Life Expectancy)'>

# %%
x = data['Generosity']
y = data['Dystopia Residual']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Dystopia Residual'>

# %%
sns.regplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Dystopia Residual'>

# %%
sns.pairplot(data)

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.offline
import warnings
warnings.filterwarnings('ignore')
